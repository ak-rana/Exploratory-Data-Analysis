# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:/Users/akank/Downloads/Club Committee Nominations _ 2023-24  (Responses) - Form Responses 1.csv")

# %%
df.head()
# Out:
#             Timestamp                 Name        Phone Number   \
# 0  4/14/2023 14:21:57    4/14/2023 14:21:57  4/14/2023 14:21:57
# 1  4/14/2023 14:23:28        Aditya Agarwal          9664401459
# 2  4/14/2023 14:46:40      Katreddi Rohith           7396430918
# 3  4/14/2023 14:52:19  N.surya Karthikeyan           9490324758
# 4  4/14/2023 15:37:16      Shashank Goswami          9643840314
#
#         Course & Batch                Post  For the post of President   \
# 0    4/14/2023 14:21:57  4/14/2023 14:21:57         4/14/2023 14:21:57
# 1      B.tech CSE(2022)      Vice President                        NaN
# 2            Btech 2021           President                        PAC
# 3          Btech ECOMP       Vice President                        NaN
# 4  B.Tech (CSE) 2021-25           President                        ACM
#
#   For the post of Vice President   \
# 0              4/14/2023 14:21:57
# 1                             NSS
# 2                             NaN
# ...

# %%
ax = sns.countplot(x=df.columns[5], data=df)
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# Out:
# [Text(0, 0, '4/14/2023 14:21:57'),
#  Text(1, 0, 'PAC'),
#  Text(2, 0, 'ACM'),
#  Text(3, 0, 'Sci-Mat'),
#  Text(4, 0, 'Environment'),
#  Text(5, 0, 'Udaan'),
#  Text(6, 0, 'SMC'),
#  Text(7, 0, 'Strokes'),
#  Text(8, 0, 'PFA'),
#  Text(9, 0, 'Savera'),
#  Text(10, 0, 'SATA'),
#  Text(11, 0, 'Culinary'),
#  Text(12, 0, 'Adventure'),
#  Text(13, 0, 'Enactus'),
#  Text(14, 0, 'NSS'),
#  Text(15, 0, 'LiQuiD'),
#  Text(16, 0, 'Wellness & Fight'),
#  Text(17, 0, 'Automobile'),
#  Text(18, 0, 'TSEC'),
#  Text(19, 0, 'Robotics')]

# %%
ax = sns.countplot(x=df.columns[6], data=df)
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# Out:
# [Text(0, 0, '4/14/2023 14:21:57'),
#  Text(1, 0, 'NSS'),
#  Text(2, 0, 'Culinary'),
#  Text(3, 0, 'Udaan'),
#  Text(4, 0, 'ACM'),
#  Text(5, 0, 'Robotics'),
#  Text(6, 0, 'Strokes'),
#  Text(7, 0, 'PFA'),
#  Text(8, 0, 'Sci-Mat'),
#  Text(9, 0, 'Enactus'),
#  Text(10, 0, 'LiQuiD'),
#  Text(11, 0, 'SMC'),
#  Text(12, 0, 'PAC'),
#  Text(13, 0, 'Sierra'),
#  Text(14, 0, 'TSEC'),
#  Text(15, 0, 'Savera'),
#  Text(16, 0, 'Automobile'),
#  Text(17, 0, 'Adventure'),
#  Text(18, 0, 'SATA'),
#  Text(19, 0, 'Environment'),
#  Text(20, 0, 'Wellness & Fight')]
