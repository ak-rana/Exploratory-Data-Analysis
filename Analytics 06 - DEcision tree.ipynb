# %%
import pandas as pd

# %%
data = pd.read_csv("C:/Users/akank/Downloads/hr_data.csv")

# %%
data
# Out:
#        SLNO  Candidate Ref DOJ Extended  Duration to accept offer  \
# 0         1        2110407          Yes                        14
# 1         2        2112635           No                        18
# 2         3        2112838           No                         3
# 3         4        2115021           No                        26
# 4         5        2115125          Yes                         1
# ...     ...            ...          ...                       ...
# 8990  12319        3822427           No                         4
# 8991  12327        3828206          Yes                         2
# 8992  12331        3834159           No                         0
# 8993  12332        3835433           No                         0
# 8994  12333        3836076           No                         2
#
#       Notice period Offered band  Pecent hike expected in CTC  \
# 0                30           E2                       -20.79
# ...

# %%
data.columns
# Out:
# Index(['SLNO', 'Candidate Ref', 'DOJ Extended', 'Duration to accept offer',
#        'Notice period', 'Offered band', 'Pecent hike expected in CTC',
#        'Percent hike offered in CTC', 'Percent difference CTC',
#        'Joining Bonus', 'Candidate relocate actual', 'Gender',
#        'Candidate Source', 'Rex in Yrs', 'LOB', 'Location', 'Age', 'Status'],
#       dtype='object')

# %%
data = data.dropna()

# %%
data
# Out:
#        SLNO  Candidate Ref DOJ Extended  Duration to accept offer  \
# 0         1        2110407          Yes                        14
# 1         2        2112635           No                        18
# 2         3        2112838           No                         3
# 3         4        2115021           No                        26
# 4         5        2115125          Yes                         1
# ...     ...            ...          ...                       ...
# 8990  12319        3822427           No                         4
# 8991  12327        3828206          Yes                         2
# 8992  12331        3834159           No                         0
# 8993  12332        3835433           No                         0
# 8994  12333        3836076           No                         2
#
#       Notice period Offered band  Pecent hike expected in CTC  \
# 0                30           E2                       -20.79
# ...

# %%
x = data[["Candidate Ref", "Duration to accept offer", "Notice period", "Percent difference CTC"]]

# %%
y = data[["Status"]]

# %%
x
# Out:
#       Candidate Ref  Duration to accept offer  Notice period Offered band  \
# 0           2110407                        14             30           E2
# 1           2112635                        18             30           E2
# 2           2112838                         3             45           E2
# 3           2115021                        26             30           E2
# 4           2115125                         1            120           E2
# ...             ...                       ...            ...          ...
# 8990        3822427                         4              0           E1
# 8991        3828206                         2              0           E1
# 8992        3834159                         0              0           E2
# 8993        3835433                         0             30           E1
# 8994        3836076                         2              0           E1
#
#       Percent difference CTC
# 0                      42.86
# ...

# %%
y
# Out:
#       Status
# 0     Joined
# 1     Joined
# 2     Joined
# 3     Joined
# 4     Joined
# ...      ...
# 8990  Joined
# 8991  Joined
# 8992  Joined
# 8993  Joined
# 8994  Joined
#
# [8995 rows x 1 columns]

# %% [markdown]
# # Determining the Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import preprocessing
le = preprocessing.LabelEncoder()

# %%
col_list = ["Candidate Ref", "Duration to accept offer", "Notice period", "Percent difference CTC","Status" ]

# %%
for i in col_list:
    data[i] = le.fit_transform(data[i])

# %%
clf=DecisionTreeClassifier(min_samples_split=1800)

# %%
clf=clf.fit(x,y)

# %%
from sklearn import tree

# %%
tree.plot_tree(clf)
# Out:
# [Text(0.6363636363636364, 0.95, 'X[2] <= 37.5\ngini = 0.304\nsamples = 8995\nvalue = [7313, 1682]'),
#  Text(0.45454545454545453, 0.85, 'X[1] <= 105.5\ngini = 0.237\nsamples = 5935\nvalue = [5119, 816]'),
#  Text(0.36363636363636365, 0.75, 'X[1] <= 70.5\ngini = 0.231\nsamples = 5904\nvalue = [5116, 788]'),
#  Text(0.2727272727272727, 0.65, 'X[2] <= 15.0\ngini = 0.224\nsamples = 5780\nvalue = [5037, 743]'),
#  Text(0.18181818181818182, 0.55, 'gini = 0.123\nsamples = 777\nvalue = [726, 51]'),
#  Text(0.36363636363636365, 0.55, 'X[3] <= -2.05\ngini = 0.238\nsamples = 5003\nvalue = [4311, 692]'),
#  Text(0.18181818181818182, 0.45, 'X[0] <= 3379952.5\ngini = 0.28\nsamples = 2005\nvalue = [1668, 337]'),
#  Text(0.09090909090909091, 0.35, 'gini = 0.297\nsamples = 1697\nvalue = [1389, 308]'),
#  Text(0.2727272727272727, 0.35, 'gini = 0.171\nsamples = 308\nvalue = [279, 29]'),
#  Text(0.5454545454545454, 0.45, 'X[3] <= 286.17\ngini = 0.209\nsamples = 2998\nvalue = [2643, 355]'),
# ...
