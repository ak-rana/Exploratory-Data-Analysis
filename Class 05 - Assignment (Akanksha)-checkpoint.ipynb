# %% [markdown]
# # Assignment

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:/Users/akank/Downloads/Business analytics/BostonHousing.csv")

# %%
df
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %% [markdown]
# # About the dataset
#
# The Boston Housing Dataset
#
# The Boston Housing Dataset is a derived from information collected by the U.S. Census Service concerning housing in the area of Boston MA. The following describes the dataset columns:
#
# - CRIM - per capita crime rate by town
# - ZN - proportion of residential land zoned for lots over 25,000 sq.ft.
# - INDUS - proportion of non-retail business acres per town.
# - CHAS - Charles River dummy variable (1 if tract bounds river; 0 otherwise)
# - NOX - nitric oxides concentration (parts per 10 million)
# - RM - average number of rooms per dwelling
# - AGE - proportion of owner-occupied units built prior to 1940
# - DIS - weighted distances to five Boston employment centres
# - RAD - index of accessibility to radial highways
# - TAX - full-value property-tax rate per 10,000
# - PTRATIO - pupil-teacher ratio by town
# - B - 1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
# - LSTAT - % lower status of the population
# - MEDV - Median value of owner-occupied homes in $1000's

# %% [markdown]
# # Question
# As always, we start off with EDA.
#
# - Give me some insights, the better they are, the better your grade looks !!
# - Then we move on to the modelling part
#
# Using all of these variables, try to fit/train a linear regression model that predicts the price of the house.
#
# The ```MEDV``` is the price columns, it is in 1000's of $.
#
# At the end, these are the things i am looking for:-
# - Your model train and test RSME
# - A python function that takes these values(training row for eg.) as input and predicts a price.
#
#
# That's all
#
# ![](https://media.tenor.com/HyDkalWyz7YAAAAd/all-the-best-best-of-luck.gif)

# %% [markdown]
# # -------------------------------------------------------------------------------------------------------
# ![gif](https://media.tenor.com/Bd8ymVteY6YAAAAC/chalein-lets-go.gif)

# %%
# Firstly, let's just briefly go through the data and what we have to begin with
df.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio           b  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %% [markdown]
# # Exploratory Data Analysis
# ![gif](https://media2.giphy.com/media/L2efPaZEZ7Ivkaqqsp/200w.gif?cid=6c09b9524yjhl7o890r2nf0jh3dn1yd6m3pbd284h6zmyc36&rid=200w.gif&ct=g)

# %%
plt.hist(df['crim'], bins=50)
plt.xlabel('Per capita crime rate')
plt.ylabel('Frequency')
plt.title('Distribution of per capita crime rate in Boston')
# Out:
# Text(0.5, 1.0, 'Distribution of per capita crime rate in Boston')

# %% [markdown]
# The visual representaion shows the "Distribution of per capita crime rate in Boston". It is observed from the Histogram:
# 1. The plot shows that the data is positively skewed, with majority of the data falls in the 0-10 range, indicating that there are some areas in Boston with much higher crime rates.
# 2. The data has a few high outliers, that falls in the approxomate range of 30-90.

# %%
sns.histplot(df['nox'], kde=True)
plt.title('Histogram of Nitric oxide concentration')
plt.show()

# %% [markdown]
# The visual representaion shows the "Histogram of Nitric Concentration". It is observed from the Histogram:
# 1. The Nitric oxide concentration in the Boston Housing dataset  is roughly normally distributed, and has peaks around 0.45 and 0.52 parts (per 10 million) approximately.
# 2. The x-axis represents the concentration of nitric oxide, while the y-axis represents the frequency or count of observations falling within a particular concentration range.
# 3. The visualization can be useful in understanding the levels of air pollution in the Boston area, as nitric oxide can be harmful to human health at high concentrations. By understanding the distribution of nitric oxide concentration in the area, the government and the policymakers can make informed decisions about air quality regulations and infrastructure development to improve public health and quality of life.

# %%
plt.scatter(df['nox'], df['crim'])
plt.xlabel('Nitric oxide concentration (parts per 10 million)')
plt.ylabel('Per capita crime rate')
plt.title('Relationship between nitric oxide concentration and per capita crime rate in Boston')
# Out:
# Text(0.5, 1.0, 'Relationship between nitric oxide concentration and per capita crime rate in Boston')

# %% [markdown]
# The visual representaion shows the "Relationship between nitric oxide concentration and per capita crime rate in Boston". It is observed from the Scatter Plot:
# 1. Suprisingly to my observation, the plot shows that there is a positive correlation between the two variables, indicating that areas with higher nitric oxide concentrations tend to have higher crime rates. That is, as the per capita crime rate increases, so does the nitric oxide concentration.
# 2. This suggests that there may be a relationship between crime and air pollution in the Boston area, although the nature of this relationship is not clear from the scatter plot alone.

# %%
sns.barplot(x="rad", y="crim", data=df)
plt.title('Relationship between the index of accessibility of radial highways and the per capita crime rate')
# Out:
# Text(0.5, 1.0, 'Relationship between the index of accessibility of radial highways and the per capita crime rate')

# %% [markdown]
# The visual representaion shows the "Relationship between the index of accessibility of radial highways and the per capita crime rate". It is observed from the Bar graph:
# 1. Each bar in the plot represents the average per capita crime rate for towns with a particular index of accessibility to radial highways.
# 2. The plot shows that the per capita crime rate is highest for towns with a radial highway accessibility index of 24, and decreases as the index decreases or increases.

# %%
plt.subplots(figsize=(10, 8))
corr_matrix = df.corr()
sns.heatmap(corr_matrix, annot=True, cmap="YlGnBu")
plt.title('Correlation matrix for Boston Housing dataset')
plt.show()

# %% [markdown]
# The visual representaion shows the "Correlation matrix for Boston Housing dataset". It is observed from the Heat Map:
# 1. It shows the correlation matrix for the Boston Housing dataset
# 2. The plot shows the correlation between each variable in the dataset, with darker colors indicating higher positive correlation and lighter colors indicating higher negative correlation.
# 3.  The plot shows that there is a strong negative correlation between the per capita crime rate and the median value of owner-occupied homes, indicating that areas with higher crime rates tend to have lower property values.
# 4. By analyzing the correlation matrix with a heatmap, we can gain insights into the relationships between variables in the Boston Housing dataset.
# 5. The heat map can be useful to derive various conclusions from the dataset which can be further used by the government for policy making and other important factors.

# %%
sns.boxplot(x="indus", data=df)
plt.xlabel('Proportion of non-retail business acres per town')
plt.title('Distribution of non-retail business acres in Boston')
# Out:
# Text(0.5, 1.0, 'Distribution of non-retail business acres in Boston')

# %% [markdown]
# The visual representaion shows the "Distribution of non-retail business acres in Boston". It is observed from the Box plot:
# 1. The median proportion of non-retail business acres per town is around 9%.
# 2. The plot also shows that the distribution is right concentrated, with more values towards the lower end of the range.
# 3. This suggests that most of the towns in the dataset have a relatively low proportion of non-retail business acres.

# %%
sns.scatterplot(x=df['rm'], y=df['medv'])
plt.xlabel('Average number of rooms per dwelling')
plt.ylabel('Median value of owner-occupied homes in $1000s')
plt.title('Scatter plot for RM vs. MEDV')
# Out:
# Text(0.5, 1.0, 'Scatter plot for RM vs. MEDV')

# %% [markdown]
# The visual representaion shows the "Scatter plot for Average number of rooms per dwelling and Median value of owner-occupied homes ". It is observed from the Scatter plot:
# 1. there is a positive linear relationship between RM and MEDV.
# 2. As the average number of rooms per dwelling increases, the median value of owner-occupied homes tends to increase as well. This suggests that homes with more rooms may be more valuable in the Boston area, all else being equal.
# 3. Overall, the scatter plot for the average number of rooms per dwelling and the median value of owner-occupied homes in $1000s can help us understand the relationship between these two variables in the Boston Housing dataset, and provide insights into the factors that affect home values in the area.

# %% [markdown]
# # ----------------------------------------------------------------------------------------------------------
# ![gif](https://media4.giphy.com/media/xUNd9QGPYSRKQqXBK0/giphy.gif)

# %% [markdown]
# # Lets begin modelling!!...

# %% [markdown]
# # Splitting Data for Training & Testing

# %%
from sklearn.model_selection import train_test_split

# %%
x = df.drop('medv',axis=1)
y = df['medv']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=0,test_size=0.6)

# %%
print(len(x_train))
print(len(x_test))
print(len(y_train))
print(len(y_test))
# Out:
# 202
# 304
# 202
# 304

# %% [markdown]
# # Fitting the Model

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_train_pred = lr.predict(x_train)

# %%
y_pred = lr.predict(x_test)

# %% [markdown]
# # Plotting the predictions for training data

# %%
plt.xlabel('index')
plt.ylabel('medv')
plt.title('Prediction')

plt.scatter(y_train_pred,y_train)


# Function add a legend  
plt.legend(["Real", "Predicted"])
plt.show()

# %% [markdown]
# # Checking Accuracy for testing data

# %%
len(y_test)
# Out:
# 304

# %%
len(y_pred)
# Out:
# 304

# %%
x_range = [i for i in range(len(y_test))]

# %%
plt.xlabel('index')
plt.ylabel('medv')
plt.title('Prediction')

plt.plot(x_range,y_test)
plt.plot(x_range,y_pred)

# Function add a legend  
plt.legend(["Real", "Predicted"])
plt.show()

# %%
plt.xlabel('index')
plt.ylabel('medv')
plt.title('Prediction')

plt.scatter(y_pred,y_test)


# Function add a legend  
plt.legend(["Real", "Predicted"])
plt.show()

# %% [markdown]
# # Looking at the score

# %%
from sklearn.metrics import r2_score,mean_squared_error

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 24.55649321654211

# %%
mse=mean_squared_error(y_test,y_pred)

# %%
# Calculate R square vale
r2_score(y_test,y_pred)
# Out:
# 0.6789917699481934

# %%
rsq = r2_score(y_test,y_pred)

# %%
print('mean squared error :',mse)
print('r square :',rsq)
# Out:
# mean squared error : 24.55649321654211
# r square : 0.6789917699481934

# %%
# why do Intercept? 
# Intecept and coeff of the line
#print('Intercept of the model:',lr.intercept_)
#print('Coefficient of the line:',lr.coef_)

# %% [markdown]
# # Creating the function

# %%
def func(a,b,c,d,e,f,g,h,i,j,k,l,m):
    temp=[]
    temp.append(lr.predict([[a,b,c,d,e,f,g,h,i,j,k,l,m]]))
    return temp

# %%
func(0.00632,18.0,2.31,0,0.538,6.575,65.2,4.0900,1,296,15.3,396.90,4.98)
# Out:
# C:\Users\akank\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# [array([30.73611952])]

# %%
#We again check for funnn! :)

func(0.06905,0.0,2.18,0,0.458,7.147,54.2,6.0622,3,222,18.7,396.90,5.33)
# Out:
# C:\Users\akank\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# [array([27.30870162])]

# %%
# That's the end of presentation.

# %% [markdown]
# # ThankYou!
# ![gif](https://media.tenor.com/YG8C8C5gkQUAAAAM/happy-tears.gif)
