# %% [markdown]
# # Assignment

# %% [markdown]
# You have already picked out the dataset you want to work with. If you have not, you can use this dataset [here](https://www.kaggle.com/datasets/blastchar/telco-customer-churn).
#
# ----
#
# # Question
# 1. EDA, i want to see some insights, present it neatly.
# 2. Fit a Decision Tree model on your data.
# 3. I want to see the training and testing accuracy of your model. So do split your data before modelling.
#
#
# ### Brownie Points (Extra 15 points)
# - Lastly, i want to see a function where i can input my values and get a prediction of whatever you are trying to predict. Think this through !!.
#
#
#
# Best of luck !!
#
# ![](https://media.tenor.com/J6BNrGi_wv8AAAAC/funny-meme.gif)

# %% [markdown]
# # ----------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Less goo!..
# ![gif](https://media.tenor.com/gLC3alr6powAAAAC/lastminute-assignment.gif)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:/Users/akank/Downloads/Business analytics/melb_data.csv")

# %%
df
# Out:
#               Suburb           Address  Rooms Type      Price Method  \
# 0         Abbotsford      85 Turner St      2    h  1480000.0      S
# 1         Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2         Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3         Abbotsford  40 Federation La      3    h   850000.0     PI
# 4         Abbotsford       55a Park St      4    h  1600000.0     VB
# ...              ...               ...    ...  ...        ...    ...
# 13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
#         SellerG        Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# ...

# %% [markdown]
# # Exploratory Data Analysis
#
# ![gif](https://thumbs.gfycat.com/BogusExhaustedElephant-size_restricted.gif)

# %%
df.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0           NaN
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# ...

# %%
plt.figure(figsize=(16, 8))
sns.countplot(x='Suburb', data=df, order=df['Suburb'].value_counts().iloc[:20].index)
plt.xticks(rotation=90)
plt.title("Count of Properties by Suburb")
plt.show()

# %% [markdown]
# The visual representaion shows the "Count of Properties by Suburb". It is observed from the Bar Plot:
#
# Insights:
#
# 1. The suburb of Reservoir has the most number of properties in the dataset, followed by Bentleigh East, Richmond and Preston.
# 2. Most suburbs have less than 1000 properties in the dataset, with only a few suburbs having more than 2000 properties.
#
# Predictions:
#
# 1. The number of properties in a suburb may be an indicator of the demand and popularity of that area, which may influence property prices and availability.

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df, x='Price', hue='Type', multiple='stack', bins=50)
plt.title("Distribution of Price by Property Type")
# Out:
# Text(0.5, 1.0, 'Distribution of Price by Property Type')

# %% [markdown]
# The visual representaion shows the "Distribution of Price by Property Type". It is observed from the Histogram:
#
# Insights:
#
# 1. Houses are the most expensive property type on average, followed by townhouses and units.
# 2. The distribution of prices for each property type is heavily right-skewed, with most properties having a price of less than $2 million.
#
# Predictions:
#
# 1. The type of property may be an important factor in determining its value, with houses likely to command higher prices than units or townhouses.

# %%
corr = df[['Rooms', 'Distance', 'Bedroom2', 'Bathroom', 'Car', 'Landsize', 'BuildingArea', 'YearBuilt', 'Price']].corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title("Correlation between Price and Property Attributes")
# Out:
# Text(0.5, 1.0, 'Correlation between Price and Property Attributes')

# %% [markdown]
# The visual representaion shows the "Correlation between Price and Property Attributes". It is observed from the Heat Map:
#
# Insights:
#
# 1. Price has the strongest positive correlation with number of rooms, number of bedrooms, number of bathrooms, and building area.
# 2. Price has a weak negative correlation with distance from the CBD and year built.
# 3. Landsize and number of car spaces have weak correlations with price.
#
# Predictions:
#
# 1. The number of rooms, bedrooms, and bathrooms, as well as the size of the building area, may be important factors in determining a property's price.
# 2. The age of the property and its distance from the CBD may also have an impact on its value.

# %%
plt.figure(figsize=(12, 8))
sns.boxplot(x='Regionname', y='Price', hue='Type', data=df)
plt.xticks(rotation=45)
plt.title("Price Distribution by Region and Property Type")
# Out:
# Text(0.5, 1.0, 'Price Distribution by Region and Property Type')

# %% [markdown]
# The visual representaion shows the "Price Distribution by Region and Property Typee". It is observed from the Box plot:
#
# Insights:
#
# 1. Houses are the most expensive property type in all regions.
# 2. Southern Metropolitan and Eastern Metropolitan regions have the highest median prices for all property types, while Western Metropolitan and Northern Victoria regions have the lowest median prices.
# 3. All regions have a wide range of prices and many outliers for all property types.
#
# Predictions:
#
# 1. The region where a property is located may be an important factor in its value, and this may vary depending on the type of property.

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Method', data=df, order=df['Method'].value_counts().index)
plt.title("Count of Properties by Method")
# Out:
# Text(0.5, 1.0, 'Count of Properties by Method')

# %% [markdown]
# The visual representaion shows the "Count of Properties by Method". It is observed from the Bar Plot:
#
# Insights:
#
# 1. Most properties in the dataset were sold by Private Treaty or S via PI (Sold after auction price not disclosed).
# 2. Very few properties were sold through Auction, VB (Vendor Bid), or W (Withdrawn).
# 3. Only a small proportion of properties were sold through SA (Sold after auction), SS (Sold before auction), or PN (Passed in).
#
# Predictions:
#
# 1. The method used to sell a property may have an impact on its price and availability.

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(x='YearBuilt', y='Price', data=df)
plt.title('Average Price of Properties by YearBuilt')
plt.title ("Average Price of Properties by YearBuilt")
# Out:
# Text(0.5, 1.0, 'Average Price of Properties by YearBuilt')

# %% [markdown]
# The visual representaion shows the "Monthly Charges by Payment Method". It is observed from the Line plot:
#
# Insights:
#
# 1. The average price of properties in Melbourne generally increases with the year of construction.
# 2. Properties built before 1900 and after 2000 have a higher average price than those built in the early 1900s to 2000.
# 3. The average price of properties built between 1910-1940 and 1980-1990 is lower than that of the other time periods.
#
# Predictions:
#
# 1. The age of a property is an important factor in determining its value, with newer and older properties tending to have a higher value than those built in the mid-1900s.
# 2. The increase in average property prices over the years suggests that the demand for housing in Melbourne has been steadily increasing.

# %% [markdown]
# # In conclusion,
# the seven visualizations we created provide several insights into the Melbourne housing market. The number of properties in a suburb, property types, number of rooms, bedrooms, bathrooms, building area, and region are important factors in determining a property's price. The method used to sell a property may also be important to consider. The age of a property is another factor to consider, with newer and older properties generally having a higher value than those built in the mid-1900s. These insights may be useful for real estate professionals and homebuyers to make informed decisions about buying and selling properties in Melbourne.The visual representaion shows the "Correlation Matrix of Numerical Features". It is observed from the Heat Map:

# %% [markdown]
# The code creates six countplots using seaborn's countplot function to visualize the relationship between various services offered by the company and customer churn. The x-axis of each plot represents a service such as phone service, internet service, streaming TV, etc., while the y-axis represents the count of customers.
#
# The insights from these plots can be used to identify which services are more likely to contribute to customer churn. For example, we can see from the plot for internet service that customers who have a fiber optic connection are more likely to churn compared to those who have DSL or no internet service at all. Similarly, we can see from the plot for streaming movies that customers who do not have this service are less likely to churn compared to those who have it.
#
# Overall, the code provides valuable insights into the relationship between various services offered by the company and customer churn, which can be used to make informed business decisions.

# %% [markdown]
# # Lets begin Modelling!!...
# # --------------------------------------------------------------------------------------------------------------

# %%
df.describe()
# Out:
#               Rooms         Price      Distance      Postcode      Bedroom2  \
# count  13580.000000  1.358000e+04  13580.000000  13580.000000  13580.000000
# mean       2.937997  1.075684e+06     10.137776   3105.301915      2.914728
# std        0.955748  6.393107e+05      5.868725     90.676964      0.965921
# min        1.000000  8.500000e+04      0.000000   3000.000000      0.000000
# 25%        2.000000  6.500000e+05      6.100000   3044.000000      2.000000
# 50%        3.000000  9.030000e+05      9.200000   3084.000000      3.000000
# 75%        3.000000  1.330000e+06     13.000000   3148.000000      3.000000
# max       10.000000  9.000000e+06     48.100000   3977.000000     20.000000
#
#            Bathroom           Car       Landsize  BuildingArea    YearBuilt  \
# count  13580.000000  13518.000000   13580.000000   7130.000000  8205.000000
# mean       1.534242      1.610075     558.416127    151.967650  1964.684217
# ...

# %%
df.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
X = df.
y = df.Price

house = ['Rooms', 'Bathroom', 'Landsize', 'Lattitude', 'Longtitude']
X = df[house]
X.describe()
# Out:
#               Rooms      Bathroom       Landsize     Lattitude    Longtitude
# count  13580.000000  13580.000000   13580.000000  13580.000000  13580.000000
# mean       2.937997      1.534242     558.416127    -37.809203    144.995216
# std        0.955748      0.691712    3990.669241      0.079260      0.103916
# min        1.000000      0.000000       0.000000    -38.182550    144.431810
# 25%        2.000000      1.000000     177.000000    -37.856822    144.929600
# 50%        3.000000      1.000000     440.000000    -37.802355    145.000100
# 75%        3.000000      2.000000     651.000000    -37.756400    145.058305
# max       10.000000      8.000000  433014.000000    -37.408530    145.526350

# %% [markdown]
# # Creating the Model

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,train_size=0.70,random_state=0)

# %%
X_train.shape
# Out:
# (9506, 5)

# %%
X_train.values.reshape(-1,1)
# Out:
# array([[  1.    ],
#        [  1.    ],
#        [  0.    ],
#        ...,
#        [319.    ],
#        [-37.7943],
#        [144.8875]])

# %%
X_train = X_train.values.reshape(-1,1)

# %%
y_train.shape
# Out:
# (9506,)

# %%
y_train.values.reshape(-1,1)
# Out:
# array([[ 312000.],
#        [1380000.],
#        [1270000.],
#        ...,
#        [1020000.],
#        [ 760000.],
#        [1225000.]])

# %%
y_train.values.reshape(-1,1).shape
# Out:
# (9506, 1)

# %% [markdown]
# # Fitting the Model

# %%
clf=DecisionTreeRegressor(min_samples_split=2000)

# %%
df.head(1)
# Out:
#        Suburb       Address  Rooms Type      Price Method SellerG       Date  \
# 0  Abbotsford  85 Turner St      2    h  1480000.0      S  Biggin  3/12/2016
#
#    Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  YearBuilt  \
# 0       2.5    3067.0  ...       1.0  1.0     202.0           NaN        NaN
#
#    CouncilArea Lattitude  Longtitude             Regionname Propertycount
# 0        Yarra  -37.7996    144.9984  Northern Metropolitan        4019.0
#
# [1 rows x 21 columns]

# %%
lf = clf.fit(train_X, train_y)

# %%
clf.predict([[2.937997,1.534242,558.416127,-37.809203,144.995216]])
# Out:
# C:\Users\akank\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# array([1497528.10298661])

# %%
y_predict = clf.predict(X_test)

# %%
y_pred
# Out:
# array([1522714.14355401,  834358.63954686,  753090.22556391, ...,
#        1522714.14355401, 1255739.24977127,  763349.77654517])

# %%
clf
# Out:
# DecisionTreeRegressor(min_samples_split=2000)

# %%
from sklearn import tree

# %%
tree.plot_tree(clf)
# Out:
# [Text(0.5769230769230769, 0.9285714285714286, 'X[0] <= 3.5\nsquared_error = 403709136629.996\nsamples = 10185\nvalue = 1075481.269'),
#  Text(0.3076923076923077, 0.7857142857142857, 'X[0] <= 2.5\nsquared_error = 227276240351.029\nsamples = 7623\nvalue = 923704.852'),
#  Text(0.15384615384615385, 0.6428571428571429, 'X[2] <= 85.5\nsquared_error = 131935134646.467\nsamples = 3257\nvalue = 720803.556'),
#  Text(0.07692307692307693, 0.5, 'squared_error = 47251704669.1\nsamples = 1315\nvalue = 553104.718'),
#  Text(0.23076923076923078, 0.5, 'squared_error = 157339603451.823\nsamples = 1942\nvalue = 834358.64'),
#  Text(0.46153846153846156, 0.6428571428571429, 'X[3] <= -37.752\nsquared_error = 244777567196.726\nsamples = 4366\nvalue = 1075067.546'),
#  Text(0.38461538461538464, 0.5, 'X[4] <= 144.886\nsquared_error = 265807596335.517\nsamples = 3104\nvalue = 1201803.314'),
# ...

# %%
plt.figure(figsize = (11,11))
tree.plot_tree(clf, fontsize=10)
plt.show()

# %% [markdown]
# # Checking test accuracy

# %%
from sklearn.metrics import r2_score,mean_squared_error

# %%
# calculate Mean square error
mean_squared_error(y_test,y_pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6560\2367322479.py in <module>
#       1 # calculate Mean square error
# ----> 2 mean_squared_error(y_test,y_pred)
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\_regression.py in mean_squared_error(y_true, y_pred, sample_weight, multioutput, squared)
#     436     0.825...
#     437     """
# --> 438     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     439         y_true, y_pred, multioutput
#     440     )
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\_regression.py in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#      92         the dtype argument passed to check_array.
#      93     """
# ---> 94     check_consistent_length(y_true, y_pred)
#      95     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
# ...

# %%
mse = mean_squared_error(y_test,y_pred_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6560\2454412054.py in <module>
# ----> 1 mse = mean_squared_error(y_test,y_pred_test)
#
# NameError: name 'y_pred_test' is not defined

# %%
rsq = r2_score(y_test,y_pred_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6560\4032672081.py in <module>
# ----> 1 rsq = r2_score(y_test,y_pred_test)
#
# NameError: name 'y_pred_test' is not defined

# %%
print('mean squared error :',mse)
print('r square :',rsq)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6560\3225072699.py in <module>
# ----> 1 print('mean squared error :',mse)
#       2 print('r square :',rsq)
#
# NameError: name 'mse' is not defined

# %% [markdown]
# # Checking train accuracy

# %%
y_pred_train = clf.predict(X_train)
# Out:
# C:\Users\akank\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6560\790941680.py in <module>
# ----> 1 y_pred_train = clf.predict(X_train)
#
# ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py in predict(self, X, check_input)
#     465         """
#     466         check_is_fitted(self)
# --> 467         X = self._validate_X_predict(X, check_input)
#     468         proba = self.tree_.predict(X)
#     469         n_samples = X.shape[0]
#
# ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py in _validate_X_predict(self, X, check_input)
#     431         """Validate the training data on predict (probabilities)."""
#     432         if check_input:
# ...

# %%
df = df.dropna()

# %%
df
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0     Female              0     Yes         No       1           No
# 1       Male              0      No         No      34          Yes
# 2       Male              0      No         No       2          Yes
# 3       Male              0      No         No      45           No
# 4     Female              0      No         No       2          Yes
# ...      ...            ...     ...        ...     ...          ...
# 7038    Male              0     Yes        Yes      24          Yes
# 7039  Female              0     Yes        Yes      72          Yes
# 7040  Female              0     Yes        Yes      11           No
# 7041    Male              1     Yes         No       4          Yes
# 7042    Male              0      No         No      66          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0     No phone service             DSL             No          Yes
# ...

# %%
col_list = ["gender", "Partner", "Dependents","PhoneService", "MultipleLines", "InternetService", "OnlineSecurity", "OnlineBackup", "DeviceProtection","TechSupport", "StreamingTV", "StreamingMovies", "Contract", "PaperlessBilling", "PaymentMethod", "Churn"]

# %%
for i in col_list:
    df[i] = le.fit_transform(df[i])

# %%
df
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0          0              0        1           0       1             0
# 1          1              0        0           0      34             1
# 2          1              0        0           0       2             1
# 3          1              0        0           0      45             0
# 4          0              0        0           0       2             1
# ...      ...            ...      ...         ...     ...           ...
# 7038       1              0        1           1      24             1
# 7039       0              0        1           1      72             1
# 7040       0              0        1           1      11             0
# 7041       1              1        1           0       4             1
# 7042       1              0        0           0      66             1
#
#       MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# ...

# %% [markdown]
# # Creating the Model

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop('Churn', axis = 1)
X.head()
# Out:
#    gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0       0              0        1           0       1             0
# 1       1              0        0           0      34             1
# 2       1              0        0           0       2             1
# 3       1              0        0           0      45             0
# 4       0              0        0           0       2             1
#
#    MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# 0              1                0               0             2
# 1              0                0               2             0
# 2              0                0               2             2
# 3              1                0               2             0
# 4              0                1               0             0
#
#    DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# 0                 0            0            0                0         0
# ...

# %%
y = df['Churn']
y.head()
# Out:
# 0    0
# 1    0
# 2    1
# 3    0
# 4    1
# Name: Churn, dtype: int32

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,train_size=0.70,random_state=0)

# %%
X_train.shape
# Out:
# (4922, 19)

# %%
X_train.values.reshape(-1,1)
# Out:
# array([[0.0000e+00],
#        [1.0000e+00],
#        [1.0000e+00],
#        ...,
#        [1.0000e+00],
#        [1.0465e+02],
#        [6.8898e+03]])

# %%
y_train.shape
# Out:
# (4922,)

# %%
y_train.values.reshape(-1,1)
# Out:
# array([[0],
#        [0],
#        [0],
#        ...,
#        [1],
#        [0],
#        [0]])

# %% [markdown]
# # Fitting the Model

# %%
#As the target variable "Churn" is a classified data. We use Decision Tree Classifier 
clf=DecisionTreeClassifier(min_samples_split=1500)

# %%
clf = clf.fit(X_train, y_train)

# %%
clf.predict([[0,0,1,1,11,0,1,0,2,0,0,0,0,0,0,1,2,29.60,346.45]])
# Out:
# C:\Users\akank\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0])

# %%
y_pred = clf.predict(X_test)

# %%
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
y_test
# Out:
# 5561    0
# 5814    0
# 2645    0
# 3983    1
# 6438    1
#        ..
# 4108    0
# 2687    0
# 5843    0
# 3576    0
# 2593    0
# Name: Churn, Length: 2110, dtype: int32

# %%
clf
# Out:
# DecisionTreeClassifier(min_samples_split=1500)

# %%
from sklearn import tree

# %%
tree.plot_tree(clf)
# Out:
# [Text(0.5555555555555556, 0.875, 'X[14] <= 0.5\ngini = 0.391\nsamples = 4922\nvalue = [3608, 1314]'),
#  Text(0.3333333333333333, 0.625, 'X[8] <= 0.5\ngini = 0.49\nsamples = 2720\nvalue = [1555, 1165]'),
#  Text(0.2222222222222222, 0.375, 'X[4] <= 7.5\ngini = 0.5\nsamples = 1836\nvalue = [901, 935]'),
#  Text(0.1111111111111111, 0.125, 'gini = 0.45\nsamples = 734\nvalue = [251, 483]'),
#  Text(0.3333333333333333, 0.125, 'gini = 0.484\nsamples = 1102\nvalue = [650, 452]'),
#  Text(0.4444444444444444, 0.375, 'gini = 0.385\nsamples = 884\nvalue = [654, 230]'),
#  Text(0.7777777777777778, 0.625, 'X[17] <= 93.675\ngini = 0.126\nsamples = 2202\nvalue = [2053, 149]'),
#  Text(0.6666666666666666, 0.375, 'X[14] <= 1.5\ngini = 0.073\nsamples = 1656\nvalue = [1593, 63]'),
#  Text(0.5555555555555556, 0.125, 'gini = 0.128\nsamples = 756\nvalue = [704, 52]'),
#  Text(0.7777777777777778, 0.125, 'gini = 0.024\nsamples = 900\nvalue = [889, 11]'),
# ...

# %%
y_pred_train = clf.predict(X_train)

# %%
y_train
# Out:
# 6814    0
# 791     0
# 562     0
# 298     0
# 5156    0
#        ..
# 4939    0
# 3269    0
# 1658    1
# 2612    0
# 2737    0
# Name: Churn, Length: 4922, dtype: int32

# %%
from sklearn.metrics import accuracy_score

# %%
#I checked if the data could actually predict correct values using accuracy score.
acc_DT = accuracy_score(y_test, y_pred)

# %%
acc_DT
# Out:
# 0.7838862559241706

# %% [markdown]
# The accuracy score of 0.7838862559241706 represents that the model is able to correctly predict the outcome of the target variable for 78.39% of the data points.

# %% [markdown]
# # Making Prediction putting other random values

# %%
#Index 3 from the dataset
clf.predict([[1,0,0,0,45,0,1,0,2,0,2,2,0,0,1,0,0,42.30,1840.75]])
# Out:
# C:\Users\akank\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0])

# %% [markdown]
# # Creating the Function

# %%
from sklearn.preprocessing import LabelEncoder
def predict_churn(gender,SeniorCitizen,Partner,Dependents,tenure,PhoneService,MultipleLines,InternetService,OnlineSecurity,OnlineBackup,DeviceProtection,TechSupport,StreamingTV,StreamingMovies,Contract,PaperlessBilling,PaymentMethod,MonthlyCharges,TotalCharges):
    
    # Create a DataFrame with the input values
    input_df = pd.DataFrame([[gender, SeniorCitizen, Partner, Dependents, tenure, PhoneService, MultipleLines, InternetService, OnlineSecurity, OnlineBackup, DeviceProtection, TechSupport, StreamingTV, StreamingMovies, Contract, PaperlessBilling, PaymentMethod, MonthlyCharges, TotalCharges]],
                            columns=['gender','SeniorCitizen','Partner','Dependents','tenure','PhoneService','MultipleLines','InternetService','OnlineSecurity','OnlineBackup','DeviceProtection','TechSupport','StreamingTV','StreamingMovies','Contract','PaperlessBilling','PaymentMethod','MonthlyCharges','TotalCharges'])
    
    # Convert categorical variables to numeric
    col_list = ["gender", "Partner", "Dependents","PhoneService", "MultipleLines", "InternetService", "OnlineSecurity", "OnlineBackup", "DeviceProtection","TechSupport", "StreamingTV", "StreamingMovies", "Contract", "PaperlessBilling", "PaymentMethod"]
    le = LabelEncoder()
    for i in col_list:
        input_df[i] = le.fit_transform(input_df[i])
    
    # Make predictions using the model
    prediction = clf.predict(input_df)
    
    # Convert the predicted output to a string value
    churn = 'Yes' if prediction == 1 else 'No'
    
    return churn

# %%
predict_churn(1,0,0,0,66,1,0,1,2,0,2,2,2,2,2,1,0,105.65,6844.50)
# Out:
# 'No'

# %% [markdown]
# ![gif](https://media.tenor.com/q88U6Hmj7zcAAAAM/god-i-hope-this-works-eric-cartman.gif)

# %% [markdown]
# # ------------------------------------------------------------------------------------------------------------
# # ThankYou!
# ![gif](https://media.tenor.com/YG8C8C5gkQUAAAAM/happy-tears.gif)
